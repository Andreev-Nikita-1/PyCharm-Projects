# %% [markdown]
# # Домашнее задание 3
# ### Андреев Никита

# %%
import sys
import time
import matplotlib.pyplot as plt
import pylab
import numpy as np
import scipy
import scipy.optimize as opt
import scipy.sparse
import sklearn.datasets

# %% [markdown]
# Функции оракулов:

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def oracle(w, X, labels, order=0, no_function=False):
    Xw = X.dot(w)
    sigmoids = sigmoid(labels * Xw)

    f = 0
    if not no_function:
        f = -1 / X.shape[0] * np.sum(np.log(sigmoids))

    if order == 0:
        return f

    grad_coeffs = labels * (1 - sigmoids)
    X1 = X.multiply(grad_coeffs.reshape(-1, 1))
    g = -1 / X.shape[0] * np.array(X1.sum(axis=0)).reshape(X.shape[1])

    if order == 1:
        return f, g, 0

    hess_coeffs = sigmoids * (1 - sigmoids)
    h = lambda v: 1 / X.shape[0] * X.transpose().dot(X.dot(v) * hess_coeffs)

    if order == 2:
        return f, g, h

# %% [markdown]
# ## В качестве данных впредь будем использовать три датасета:

# %% [markdown]
# a1a:

# %%
a1a = sklearn.datasets.load_svmlight_file('../data/a1a.txt')
X = a1a[0]
dummy = scipy.sparse.csr_matrix([[1] for i in range(X.shape[0])])
X_a1a = scipy.sparse.hstack([X, dummy])
labels_a1a = a1a[1]

# %% [markdown]
# breast cancer: (координаты нормированы от -1 до 1)

# %%
breast_cancer = sklearn.datasets.load_svmlight_file('../data/breast-cancer_scale.txt')
X = breast_cancer[0]
dummy = scipy.sparse.csr_matrix([[1] for i in range(X.shape[0])])
X_cancer = scipy.sparse.hstack([X, dummy])
labels_cancer = breast_cancer[1]-3

# %% [markdown]
# Случайный сгенерированный:

# %%
def random_dataset(alpha, beta):
    xs = np.random.normal(size=(1000, alpha.shape[0]))
    labels = np.array([np.sign(np.dot(alpha, x) + beta) for x in xs])
    return xs, labels

# %%
alpha = 2 * np.random.random(11) - 1
X, labels_rand = random_dataset(alpha[:-1], alpha[-1])
dummy = scipy.sparse.csr_matrix([[1] for i in range(X.shape[0])])
X_rand = scipy.sparse.hstack([X, dummy])

# %% [markdown]
# #### Методы из дз 2 и 3:

# %%
def golden_search_bounded(fun, a0, b0, eps=10 * sys.float_info.epsilon, args=()):
    ratio = (1 + 5 ** 0.5) / 2
    a, b, c, d = a0, b0, (b0 - a0) / ratio + a0, b0 - (b0 - a0) / ratio
    fc, fd = fun(c, *args), fun(d, *args)
    onumber = 2
    while True:
        if b - a <= eps:
            return c, onumber
        if fc < fd:
            c, d, b = a + d - c, c, d
            fd = fc
            fc = fun(c, *args)
            onumber += 1
        else:
            a, c, d = c, d, b - d + c
            fc = fd
            fd = fun(d, *args)
            onumber += 1


def golden_search(fun, eps=10*sys.float_info.epsilon, args=()):
    a, _, b, _, _, _, onumber = opt.bracket(fun, args=args)
    if b < a:
        a, b = b, a
    gsb = golden_search_bounded(fun, a, b, eps=eps, args=args)
    return gsb[0], gsb[1] + onumber


def armiho(fun, c=0.1, k=10, f0=None, df0=None):
    x = 1
    oracle = 0

    if f0 == None:
        f0 = fun(0)
        oracle += 1

    if df0 is None:
        df0 = der(fun, 0)
        oracle += 2

    fx = fun(x)
    fkx = fun(k * x) 
    oracle += 2

    while True:
        if fx > f0 + c * df0 * x:
            x /= k
            fkx = fx
            fx = fun(x)
            oracle += 1
        elif fkx < f0 + k * c * df0 * x:
            x *= k
            fx = fkx
            fkx = fun(k*x)
            oracle += 1
        else:
            break

    return x, fx, oracle


def nester(fun, f0, d, L0=1):
    L = L0
    oracle = 0
    fx = fun(1 / L)
    oracle += 1
    
    while fx > f0 - 1 / (2 * L) * np.dot(d, d):
        L *= 2
        fx = fun(1 / L)
        oracle += 1
    

    return L, fx, oracle

def solveCholesky(h, d, eps=0.0001):
    G = np.array([h(x) for x in np.eye(d.shape[0])])
    if np.linalg.matrix_rank(G) < G.shape[0]:
        G = G + eps * np.eye(G.shape[0])
    L = np.linalg.cholesky(G)
    Ltx = scipy.linalg.solve_triangular(L, d, lower=True)
    return scipy.linalg.solve_triangular(np.transpose(L), Ltx, lower=False)

def solveCG(h, b, eta=0.5, policy='sqrtGradNorm'):
    b_norm = np.linalg.norm(b)
    if policy == 'sqrtGradNorm':
        tol = min(np.sqrt(b_norm), 0.5)
    elif policy == 'gradNorm':
        tol = min(b_norm, 0.5)
    elif policy == 'const':
        tol = eta

    eps = tol * b_norm
    x0 = np.random.random(b.shape[0]) * b_norm
    r = b - h(x0)
    p = r
    x = x0
    hc = 1

    while True:
        rr = r.dot(r)
        hp = h(p)
        hc += 1
        alpha = rr / np.dot(p, hp)
        x += alpha * p
        r -= alpha * hp
        if np.linalg.norm(r) < eps:
            break
        beta = r.dot(r) / rr
        p = r + beta * p
    return x, hc

# %% [markdown]
# ### Реализация BFGS и L-BFGS:

# %%
class BFGS:
    def __init__(self, H0):
        self.Hk = H0

    def update(self, s, y):
        sty = np.dot(s, y)
        Hky = self.Hk.dot(y)
        sHky = np.outer(s, Hky)
        self.Hk += (sty + np.dot(y, Hky)) / sty**2 * np.outer(
            s, s) - (sHky + sHky.T) / sty

# %%
class LBFGS:
    def __init__(self, m):
        self.ys = []
        self.ss = []
        self.stys = []
        self.m = m

    def update(self, s, y):
        self.ss.append(s)
        self.ys.append(y)
        self.stys.append(np.dot(s, y))
        if len(self.ss) > self.m:
            self.ss = self.ss[1:]
            self.ys = self.ys[1:]
            self.stys = self.stys[1:]

    def direction(self, g):
        stgs = []
        for y, s, sty in list(zip(self.ys, self.ss, self.stys))[::-1]:
            stgs.append(np.dot(s, g))
            g -= y * stgs[-1] / sty
        g *= self.stys[-1] / np.dot(self.ys[-1], self.ys[-1])
        for y, s, sty, stg in zip(self.ys, self.ss, self.stys, stgs[::-1]):
            g += (-np.dot(y, g) + stg) / sty * s
        return g

# %% [markdown]
# ## Градиентный спуск и метод Ньютона:
#
# Разница только в выборе направления - поэтому всё в одном методе
#
# Параметры:
#
# 1. oracle - оракул
# 2. start - начальная точка
# 3. method - 'gradient descent', 'newton', 'BFGS' или 'L-BFGS'
# 4. __linear_solver - 'cg' или 'cholesky'__
# 5. __solver_kwargs - аргументы для linear_solver__
# 6. H0 - начальное значение B^-1 для BFGS (по умолчанию - E)
# 6. m - длина истории для L-BFGS
# 6. one_dim_search - способ выбора шага:
#     'unit step',
#     'brent',
#     'golden',
#     'armiho',
#     'nester',
#     'wolf',
#     или пользовательский метод
# 7. args - аргументы для оракула (X, labels, outers(опционально))
# 8. search_kwargs - аргументы для метода одномерной оптимизации
# 9. условие(я) остановки: epsilon, max_iter, max_time, max_oracle
#
#
# Возвращает:
#
# 1. x - результат
# 2. iterations - range от 0 до количества итераций
# 3. times - массив времён от начала вычисления до текущего шага
# 4. values - массив значений функции
# 5. grad_ratios - массив отношений $||\nabla f(w_k)||^2/||\nabla f(w_0)||^2$
# 6. fcalls - масиив количества вызовов функции на каждой итерации
# 7. gcalls - аналогично для градиента
# 8. hcalls - аналогично для гессиана
#
# В реализации в main.py возвращаются только последние элементы перечисленных массивов

# %%
def optimization_task(oracle,
                      start,
                      method='gradient descent',
                      linear_solver='cg',
                      solver_kwargs=dict([]),
                      H0=None,
                      m=20,
                      one_dim_search=None,
                      args=(),
                      search_kwargs=dict([]),
                      epsilon=0,
                      max_iter=float('inf'),
                      max_time=float('inf')):

    iterations, fcalls, gcalls, hcalls, times, values, grad_ratios = [], [], [], [], [], [], []
    start_time, k, fc, gc, hc = time.time(), 0, 0, 0, 0
    x = start

    if method == 'gradient descent':
        ord = 1
        if one_dim_search is None:
            one_dim_search = 'armiho'
    elif method == 'newton' or method == 'BFGS' or method == 'L-BFGS':
        ord = 2
        if one_dim_search is None:
            one_dim_search = 'unit step'

    f0, g0, _ = oracle(x, *args, order=1)
    fc += 1
    gc += 1
    fk = f0

    if method == 'BFGS' or method == 'L-BFGS':
        init = True

    if one_dim_search == 'nester':
        L, L0 = 2, 0
        if 'L0' in search_kwargs.keys():
            L0 = 2 * search_kwargs['L0']
            L = L0

    flag = one_dim_search == 'armiho' or one_dim_search == 'wolf' or one_dim_search == 'nester'

    while True:
        f_, gk, hk = oracle(x, *args, order=ord, no_function=flag)
        # в реализации в main.py всегда стоит флаг no_function
        if not flag:
            fk = f_
            fc += 1
        gc += 1
        if ord == 2:
            hc += 1

        ratio = np.dot(gk, gk) / np.dot(g0, g0)
        iterations.append(k)
        fcalls.append(fc)
        gcalls.append(gc)
        hcalls.append(hc)
        times.append(time.time() - start_time)
        values.append(fk)
        grad_ratios.append(ratio)

        if ratio <= epsilon or k > max_iter or times[-1] > max_time:
            break

        k += 1

        if method == 'gradient descent':
            d = -gk
        elif method == 'newton':
            if linear_solver == 'cg':
                d, oracle_counter = solveCG(hk, -gk, **solver_kwargs)
                hc += oracle_counter
            elif linear_solver == 'cholesky':
                d = solveCholesky(hk, -gk, **solver_kwargs)
        elif method == 'BFGS':
            if init:
                init = False
                bfgs = BFGS(H0 if H0 is not None else np.eye(x.shape[0]))
            else:
                bfgs.update(x - prev_x, gk - prev_gk)
            d = -bfgs.Hk.dot(gk)

        elif method == 'L-BFGS':
            if init:
                init = False
                lbfgs = LBFGS(m)
                d = -gk
            else:
                lbfgs.update(x - prev_x, gk - prev_gk)
                d = -lbfgs.direction(np.copy(gk))

        fun = lambda alpha: oracle(x + d * alpha, *args)

        if one_dim_search == 'unit step':
            alpha = 1
        elif one_dim_search == 'golden':
            alpha, oracle_counter = golden_search(fun, **search_kwargs)
            fc += oracle_counter
        elif one_dim_search == 'brent':
            solution = opt.minimize_scalar(fun)
            alpha = solution['x']
            fc += solution['nfev']
        elif one_dim_search == 'armiho':
            alpha, fk, oracle_counter = armiho(fun,
                                               **search_kwargs,
                                               f0=fk,
                                               df0=np.dot(gk, d))
            fc += oracle_counter
        elif one_dim_search == 'wolf':
            f_for_wolf = lambda z: oracle(z, *args)
            g_for_wolf = lambda z: oracle(z, *args, order=1, no_function=True)[
                1]
            solution = opt.line_search(f_for_wolf,
                                       g_for_wolf,
                                       x,
                                       d,
                                       **search_kwargs,
                                       gfk=gk,
                                       old_fval=fk)
            alpha = solution[0]
            if alpha == None:
                alpha = 1
            fc += solution[1]
            gc += solution[2]
            fk = solution[3]
            if fk == None:
                fk = fun(1)
        elif one_dim_search == 'nester':
            L, fk, oracle_counter = nester(fun, fk, gk, L0=max(L / 2, L0))
            alpha = 1 / L
            fc += oracle_counter
        else:
            alpha = one_dim_search(fun, *args)

        if method == 'BFGS' or method == 'L-BFGS':
            prev_gk = gk
            prev_x = x

        x = x + d * alpha

    return x, iterations, times, values, grad_ratios, fcalls, gcalls, hcalls

# %% [markdown]
# #### Метод для построения нескольких графиков (десятичных) логарифмов функций

# %%
def graph_several(xs, ys, labels, end=None, beg=0, x_l=None, y_l=None, title=None):
    pylab.rcParams['figure.figsize'] = 15, 7
    pylab.subplot(1, 1, 1)
    if end is None:
        end = max([max(x) for x in xs])
    ends = [np.argmin([np.abs(p - end) for p in x]) for x in xs]
    begs = [np.argmin([np.abs(p - beg) for p in x]) for x in xs]
    xs1 = [xs[i][begs[i]:ends[i]+1] for i in range(len(xs))]
    ys1 = [ys[i][begs[i]:ends[i]+1] for i in range(len(xs))]

    def logs(y):
        return [np.log10(v) for v in y]

    for i in range(len(xs)):
        pylab.plot(xs1[i], logs(ys1[i]), label=labels[i])

    pylab.title(title)
    pylab.xlabel(x_l)
    pylab.ylabel(y_l)
    pylab.grid()
    pylab.legend()
    pylab.show()

# %%
def graph_several2(xs, ys, labels, end1=None, beg1=0, end2=None, beg2=0, x_l=None, y_l=None, title=None):
    pylab.rcParams['figure.figsize'] = 15, 7
    pylab.subplot(1, 2, 1)
    if end1 is None:
        end1 = max([max(x) for x in xs])
    ends = [np.argmin([np.abs(p - end1) for p in x]) for x in xs]
    begs = [np.argmin([np.abs(p - beg1) for p in x]) for x in xs]
    xs1 = [xs[i][begs[i]:ends[i]+1] for i in range(len(xs))]
    ys1 = [ys[i][begs[i]:ends[i]+1] for i in range(len(xs))]

    def logs(y):
        return [np.log10(v) for v in y]

    for i in range(len(xs)):
        pylab.plot(xs1[i], logs(ys1[i]), label=labels[i])

    pylab.title(title)
    pylab.xlabel(x_l)
    pylab.ylabel(y_l)
    pylab.grid()
    pylab.legend()
    
    pylab.subplot(1, 2, 2)
    if end2 is None:
        end2 = max([max(x) for x in xs])
    ends = [np.argmin([np.abs(p - end2) for p in x]) for x in xs]
    begs = [np.argmin([np.abs(p - beg2) for p in x]) for x in xs]
    xs1 = [xs[i][begs[i]:ends[i]+1] for i in range(len(xs))]
    ys1 = [ys[i][begs[i]:ends[i]+1] for i in range(len(xs))]

    def logs(y):
        return [np.log10(v) for v in y]

    for i in range(len(xs)):
        pylab.plot(xs1[i], logs(ys1[i]), label=labels[i])

    pylab.title(title)
    pylab.xlabel(x_l)
    pylab.ylabel(y_l)
    pylab.grid()
    pylab.legend()
    
    pylab.show()

# %% [markdown]
# #### Минимальные значения функций с помощью встроенных методов:

# %%
w0_a1a = (2 * np.random.random(X_a1a.shape[1]) - 1) / 2
#начальная точка

w_true_a1a = opt.minimize(oracle, w0_a1a, args=(X_a1a, labels_a1a), jac = lambda x, X, l: oracle(x, X, l, order=1, no_function=True)[1])['x']

f_min_a1a = oracle(w_true_a1a, X_a1a, labels_a1a)
print('a1a function minimum =', f_min_a1a)
# Out:
# a1a function minimum = 0.2978762324444192

# %%
w0_cancer = (2 * np.random.random(X_cancer.shape[1]) - 1) / 2
#начальная точка

w_true_cancer = opt.minimize(oracle, w0_cancer, args=(X_cancer, labels_cancer), jac = lambda x, X, l: oracle(x, X, l, order=1, no_function=True)[1])['x']

f_min_cancer = oracle(w_true_cancer, X_cancer, labels_cancer)
print('cancer function minimum =', f_min_cancer)
# Out:
# cancer function minimum = 0.07531873714441012

# %%
w0_rand = (2 * np.random.random(X_rand.shape[1]) - 1) / 2
#начальная точка


f_min_rand = 0
print('rand function minimum =', f_min_rand)
# Out:
# rand function minimum = 0

# %% [markdown]
# ## Сравнение стратегий линейного поиска:

# %% [markdown]
# #### BFGS:

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_a1a, method='BFGS', one_dim_search='unit step',
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_a1a, method='BFGS', one_dim_search='armiho',
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_a1a, method='BFGS', one_dim_search='wolf',
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_a1a, method='BFGS', one_dim_search='brent',
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
graph_several([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='time', y_l='gradNorm ratio', title='a1a')

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='iteration', y_l='gradNorm ratio', title='a1a')

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_cancer, method='BFGS', one_dim_search='unit step',
                                                      args=[X_cancer, labels_cancer], max_time=0.3)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_cancer, method='BFGS', one_dim_search='armiho',
                                                      args=[X_cancer, labels_cancer], max_time=0.3)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_cancer, method='BFGS', one_dim_search='wolf',
                                                      args=[X_cancer, labels_cancer], max_time=0.3)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_cancer, method='BFGS', one_dim_search='brent',
                                                      args=[X_cancer, labels_cancer], max_time=0.3)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
graph_several2([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='time', y_l='gradNorm ratio', title='cancer', end2=0.05)

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='iteration', y_l='gradNorm ratio', title='cancer', end=120)

# %% [markdown]
# #### L-BFGS:

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_a1a, method='L-BFGS', one_dim_search='unit step',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_a1a, method='L-BFGS', one_dim_search='armiho',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_a1a, method='L-BFGS', one_dim_search='wolf',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_a1a, method='L-BFGS', one_dim_search='brent',
                                                      args=[X_a1a, labels_a1a], max_time=2)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars

# %%
graph_several([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='time', y_l='gradNorm ratio', title='a1a')

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='iteration', y_l='gradNorm ratio', title='a1a')

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_cancer, method='L-BFGS', one_dim_search='unit step',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_cancer, method='L-BFGS', one_dim_search='armiho',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_cancer, method='L-BFGS', one_dim_search='wolf',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_cancer, method='L-BFGS', one_dim_search='brent',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\Nikita\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
graph_several2([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='time', y_l='gradNorm ratio', title='cancer', end2=0.05)

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['unit step', 'armiho', 'wolf', 'brent'], 
               x_l='iteration', y_l='gradNorm ratio', title='cancer', end=120)

# %% [markdown]
# В данных примерах единичный шаг показывает лучшие результаты

# %% [markdown]
# ## Выбор длины истории для L-BFGS:

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_a1a, method='L-BFGS', m=1,
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_a1a, method='L-BFGS', m=10,
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_a1a, method='L-BFGS', m=30,
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_a1a, method='L-BFGS', m=100,
                                                      args=[X_a1a, labels_a1a], max_time=1.5)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars

# %%
graph_several2([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['m=1', 'm=10', 'm=30', 'm=100'], 
               x_l='time', y_l='gradNorm ratio', title='a1a', end2=0.2)

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['m=1', 'm=10', 'm=30', 'm=100'], 
               x_l='iteration', y_l='gradNorm ratio', title='a1a')

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_cancer, method='L-BFGS', m=1,
                                                      args=[X_cancer, labels_cancer], max_time=1)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_cancer, method='L-BFGS', m=10,
                                                      args=[X_cancer, labels_cancer], max_time=1)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_cancer, method='L-BFGS', m=30,
                                                      args=[X_cancer, labels_cancer], max_time=1)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_cancer, method='L-BFGS', m=100,
                                                      args=[X_cancer, labels_cancer], max_time=1)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
graph_several2([t1, t2, t3, t4], [r1, r2, r3, r4], labels=['m=1', 'm=10', 'm=30', 'm=100'], 
               x_l='time', y_l='gradNorm ratio', title='cancer', end2=0.05)

# %%
graph_several([i1, i2, i3, i4], [r1, r2, r3, r4], labels=['m=1', 'm=10', 'm=30', 'm=100'], 
               x_l='iteration', y_l='gradNorm ratio', title='cancer', end=120)

# %% [markdown]
# Большая длина истории даёт лучшие результаты - логично. Но занимает больше памяти

# %% [markdown]
# ## Сравнение BFGS, L-BFGS и других методов:

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_a1a, method='BFGS',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_a1a, method='L-BFGS',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_a1a, method='newton', linear_solver='cg',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_a1a, method='newton', linear_solver='cholesky',
                                                      args=[X_a1a, labels_a1a], max_time=2)
a5, i5, t5, v5, r5, fc5, gc5, hc5 = optimization_task(oracle, w0_a1a, method='gradient descent',
                                                      args=[X_a1a, labels_a1a], max_time=2)
# Out:
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Nikita\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
graph_several([t1, t2, t3, t4, t5], [r1, r2, r3, r4, r5], labels=['BFGS', 'L-BFGS', 'newton cg', 'newton cholesky', 'gradient descent'], 
               x_l='time', y_l='gradNorm ratio', title='a1a')

# %%
graph_several([i1, i2, i3, i4, i5], [r1, r2, r3, r4, r5], labels=['BFGS', 'L-BFGS', 'newton cg', 'newton cholesky', 'gradient descent'], 
               x_l='time', y_l='gradNorm ratio', title='a1a')

# %%
a1, i1, t1, v1, r1, fc1, gc1, hc1 = optimization_task(oracle, w0_cancer, method='BFGS',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a2, i2, t2, v2, r2, fc2, gc2, hc2 = optimization_task(oracle, w0_cancer, method='L-BFGS',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a3, i3, t3, v3, r3, fc3, gc3, hc3 = optimization_task(oracle, w0_cancer, method='newton', linear_solver='cg',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a4, i4, t4, v4, r4, fc4, gc4, hc4 = optimization_task(oracle, w0_cancer, method='newton', linear_solver='cholesky',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)
a5, i5, t5, v5, r5, fc5, gc5, hc5 = optimization_task(oracle, w0_cancer, method='gradient descent',
                                                      args=[X_cancer, labels_cancer], max_time=0.2)

# %%
graph_several2([t1, t2, t3, t4, t5], [r1, r2, r3, r4, r5], labels=['BFGS', 'L-BFGS', 'newton cg', 'newton cholesky', 'gradient descent'], 
               x_l='time', y_l='gradNorm ratio', title='cancer', end2=0.03)

# %%
graph_several([i1, i2, i3, i4, i5], [r1, r2, r3, r4, r5], labels=['BFGS', 'L-BFGS', 'newton cg', 'newton cholesky', 'gradient descent'], 
               x_l='time', y_l='gradNorm ratio', title='a1a')

# %% [markdown]
# BFGS и L-BFGS работают по времени примерно как и newton, но итераций выполняется больше
